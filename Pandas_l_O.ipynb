# %% [markdown]
# <a href="https://colab.research.google.com/github/leriverah/Pandas_Learning/blob/main/Pandas_l_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Leyendo archicos CSV**

# %% [markdown]
# ## **Importando archivos CSV**

# %%
import pandas as pd

# %%
datos = pd.read_csv('superstore_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4888b7aec79d> in <cell line: 0>()
# ----> 1 datos = pd.read_csv('superstore_data.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
datos.head()

# %%
datos_punto_coma = pd.read_csv('superstore_data_punto_coma.csv')

# %%
datos_punto_coma.head()

# %%
import chardet

with open('superstore_data_punto_coma.csv', 'rb') as file:
    print(chardet.detect(file.read()))

# %%
df = pd.read_csv('superstore_data_punto_coma.csv', encoding='ascii')
df.head()

# %% [markdown]
# ### **Parametros de la funcion read.csv**

# %%
datos_punto_coma = pd.read_csv('superstore_data_punto_coma.csv', sep = ';')
datos_punto_coma.head()

# %%
# Para trabajar solo con lineas

datos_primeras_lineas = pd.read_csv('superstore_data.csv', nrows= 5)
datos_primeras_lineas

# %%
# Tambien puede colocarse el nombre de la columna

datos_seleccion = pd.read_csv('superstore_data.csv', usecols = [3,8,10])
datos_seleccion

# %% [markdown]
# ### **Escribiendo archivos CSV**

# %%
# para guardar en formato CSV

datos_seleccion.to_csv('clientes_mercado.csv')

# %%
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado

# %%
datos_seleccion.to_csv('datoss_mercado.csv', index=False)

# %%
datos_mercado = pd.read_csv('datoss_mercado.csv')
datos_mercado

# %% [markdown]
# # **Leyendo arichivos Excel**

# %% [markdown]
# ## **Importando archivos Excel**

# %%
datos_excel = pd.read_excel('emisiones_CO2.xlsx')
datos_excel.head()

# %%
pd.ExcelFile('emisiones_CO2.xlsx').sheet_names

# %%
percapita = pd.read_excel('emisiones_CO2.xlsx', sheet_name='emisiones_percapita')
percapita.tail()

# %%
percapita.sample(5)

# %%
fuentes = pd.read_excel('emisiones_CO2.xlsx', sheet_name='fuentes')
fuentes.tail()

# %% [markdown]
# ### Intervalos

# %%
intervalo = pd.read_excel('emisiones_CO2.xlsx', sheet_name='emisiones_C02', usecols = 'A:D')
intervalo

# %%
intervalo2 = pd.read_excel('emisiones_CO2.xlsx', sheet_name='emisiones_C02', usecols = 'A:D', nrows=10)
intervalo2

# %% [markdown]
# ### Exporta Dataframe de Excle.

# %%
intervalo.to_excel('CO2_percapita.xlsx', index=False)

# %%
pd.read_excel('CO2_percapita.xlsx')

# %% [markdown]
# # leyendo Google Sheets

# %% [markdown]
# Url = https://docs.google.com/spreadsheets/d/1aZ4mFpB-jegnRosAjrbedJDhwSfm9reXB9-NCse06gU/edit?gid=784878386#gid=784878386

# %%
import pandas as pd

# %%
sheet_id = '1aZ4mFpB-jegnRosAjrbedJDhwSfm9reXB9-NCse06gU'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos_co2 = pd.read_csv(url)
datos_co2.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año         Total
# 63099  Global                WLD  2017  3.609674e+10
# 63100  Global                WLD  2018  3.682651e+10
# 63101  Global                WLD  2019  3.708256e+10
# 63102  Global                WLD  2020  3.526409e+10
# 63103  Global                WLD  2021  3.712385e+10

# %% [markdown]
# ## Importando arhivos Google Sheets

# %%
sheet_id = '1aZ4mFpB-jegnRosAjrbedJDhwSfm9reXB9-NCse06gU'
sheet_name = 'emisiones_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita = pd.read_csv(url_percapita)
percapita.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750    0.0
# 1  Afganistán                AFG  1751    0.0
# 2  Afganistán                AFG  1752    0.0
# 3  Afganistán                AFG  1753    0.0
# 4  Afganistán                AFG  1754    0.0

# %%
sheet_id = '1aZ4mFpB-jegnRosAjrbedJDhwSfm9reXB9-NCse06gU'
sheet_name = 'fuentes'
url_fuentes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
fuentes_sheet = pd.read_csv(url_fuentes)

# %%
fuentes_sheet.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año         Total
# 63099  Global                WLD  2017  3.609674e+10
# 63100  Global                WLD  2018  3.682651e+10
# 63101  Global                WLD  2019  3.708256e+10
# 63102  Global                WLD  2020  3.526409e+10
# 63103  Global                WLD  2021  3.712385e+10

# %% [markdown]
# # **Leyendo archivos jason**

# %% [markdown]
# ## **Importando arhicos jason**

# %%
datos_json = pd.read_json('pacientes.json')
datos_json.head()
# Out:
#    ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0            0                 No  16.60      Sí              No  No
# 1            1                 No  20.34      No              No  Sí
# 2            2                 No  26.58      Sí              No  No
# 3            3                 No  24.21      No              No  No
# 4            4                 No  23.71      No              No  No
#
#    Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# 0             3            30                 No       Femenino      55-59
# 1             0             0                 No       Femenino     80 ó +
# 2            20            30                 No      Masculino      65-69
# 3             0             0                 No       Femenino      75-79
# 4            28             0                 Sí       Femenino      40-44
#
#      Raza Diabetes Actividad_fisica Salud_general  Horas_sueño Asma  \
# ...

# %%
datos_pacientes_2 = pd.read_json('pacientes_2.json' )
datos_pacientes_2.head()
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# ### Normalizando arhivos JSON

# %%
df_normalizar = pd.json_normalize(datos_pacientes_2 ['Pacientes'])
df_normalizar
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ### Exportando el archivo Json

# %%
df_normalizar.to_json('Historico_pacientes_normalizado.json')

# %%
pd.read_json('Historico_pacientes_normalizado.json')
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# # **Leyendo archivos HTML**

# %% [markdown]
# ## **Importando archivos HTML**

# %%
import pandas as pd

# %%
dato_html = pd.read_html('peliculas_wikipedia.html')

# %%
dato_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
type(dato_html)
# Out:
# list

# %%
# tamano de lista

len(dato_html)
# Out:
# 3

# %%
top = dato_html[1]
top
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# ## **Exportando en HTML**

# %%
top.to_html('top_peliculas.html', index=False)

# %%
pd.read_html('top_peliculas.html')
# Out:
# [                            Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
#  ..                           ...           ...                   ...
#  95                 The Searchers          1956             John Ford
#  96              Bringing Up Baby          1938          Howard Hawks
#  97                    Unforgiven          1992        Clint Eastwood
#  98  Guess Who's Coming to Dinner          1967        Stanley Kramer
#  99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                        Production companies  Rank
#  0                       RKO Radio Pictures     1
# ...

# %%
top.to_csv('top_peliculas_top.csv', index=False)

# %%
datos_pd = pd.read_csv('top_peliculas_top.csv')
datos_pd.head()
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %% [markdown]
# # **Leyendo/Escribiendo archivos XML**

# %% [markdown]
# ## **Importando XML**

# %%
datos_xml = pd.read_xml ('imdb_top_1000.xml')

# %%
datos_xml.head(3)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
# ...

# %% [markdown]
# ### Escribir a HTML o Exportar

# %%
datos_xml.to_csv('peliculas_imdb_csv', index=False)

# %%
datos_xml.to_xml('peliculas_imdb_xml', index=False)

# %% [markdown]
# # **Creando Banco de datos**

# %%
import sqlalchemy as db

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %% [markdown]
# ## **Creando motor de Banco de datos**

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# ## **Escribiendo y exportando en base de datos**

# %%
import pandas as pd

# %%
datos_sql = pd.read_csv('clientes_banco.csv')
datos_sql.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable               2
# 1     5008805    32    Nivel superior  Relación-estable               2
# 2     5008806    58  Nivel intermedio            Casado               2
# 3     5008808    52  Nivel intermedio           Soltero               1
# 4     5008809    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado       Otro             12           427500.0
# 2           Empleado  Seguridad              3           112500.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# 1            1    Departamento alquilado
# ...

# %%
datos_sql.to_sql("cliente_sql", engine, index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)
print (inspector.get_table_names())
# Out:
# ['cliente_sql']

# %% [markdown]
# ### Consultas SQL 'QUERY'

# %%
query = 'SELECT * FROM cliente_sql WHERE Categoria_de_renta = "Empleado"'

# %%
empleados = pd.read_sql(sql = text(query), con = engine)

# %%
type(empleados)
# Out:
# pandas.core.frame.DataFrame

# %%
empleados.to_sql('empleados', con = engine, index=False)
# Out:
# 226059

# %%
pd.read_sql('empleados', con = engine)
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
pd.read_sql_table('empleados', con = engine, columns = {'ID_Cliente','Grado_estudio','Rendimiento_anual' })
# Out:
#         ID_Cliente  Rendimiento_anual     Grado_estudio
# 0          5008804           427500.0    Nivel superior
# 1          5008805           427500.0    Nivel superior
# 2          5008806           112500.0  Nivel intermedio
# 3          5008815           270000.0    Nivel superior
# 4          5112956           270000.0    Nivel superior
# ...            ...                ...               ...
# 226054     6837905           355050.0  Nivel intermedio
# 226055     6837906           355050.0  Nivel intermedio
# 226056     6839936           135000.0  Nivel intermedio
# 226057     6840222           103500.0  Nivel intermedio
# 226058     6842885           121500.0  Nivel intermedio
#
# [226059 rows x 3 columns]

# %% [markdown]
# ### Actualizando un banco de datos

# %%
query1 = 'SELECT * FROM empleados'

# %%
pd.read_sql(sql = text(query1), con = engine)
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008815    46    Nivel superior            Casado               2
# 3          5112956    46    Nivel superior            Casado               2
# 4          6153651    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226053     6837905    43  Nivel intermedio            Casado               3
# 226054     6837906    43  Nivel intermedio            Casado               3
# 226055     6839936    34  Nivel intermedio            Casado               3
# 226056     6840222    43  Nivel intermedio           Soltero               1
# 226057     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %% [markdown]
# ### Borrar registro

# %%
# Borrando registro
from sqlalchemy.exc import SQLAlchemyError
query1 = 'DELETE FROM empleados WHERE ID_cliente =5008804 '
try:
    r_set = engine.connect().execute(text(query1))
except SQLAlchemyError as e:
    print(e)
else:
    print('Se borro el registro', r_set.rowcount)
# Out:
# Se borro el registro 1

# %%
pd.read_sql('empleados', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008815    46    Nivel superior            Casado               2
# 3          5112956    46    Nivel superior            Casado               2
# 4          6153651    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226053     6837905    43  Nivel intermedio            Casado               3
# 226054     6837906    43  Nivel intermedio            Casado               3
# 226055     6839936    34  Nivel intermedio            Casado               3
# 226056     6840222    43  Nivel intermedio           Soltero               1
# 226057     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
# Actualizando registro

query2 = 'UPDATE empleados SET Grado_estudio="Nivel superior" WHERE ID_cliente =5008815'
try:
    r_set = engine.connect().execute(text(query2))
except SQLAlchemyError as e:
    print(e)
else:
    print('Se actualizo el registro', r_set.rowcount)
# Out:
# Se actualizo el registro 1
